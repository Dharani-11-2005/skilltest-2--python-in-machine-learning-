# %%
import pandas as pd

# a. Create lists and DataFrame
data = ["Apple", "Banana", "Cherry", "Mango", "Orange"]
prices = [120, 40, 200, 150, 80]

# Zip lists and create DataFrame
fruits_df = pd.DataFrame(list(zip(data, prices)), columns=["Fruit", "Price"])

# b. Get information about the DataFrame
print("DataFrame Info:")
print(fruits_df.info())

# c. Print the entire DataFrame
print("\nFull DataFrame:")
print(fruits_df.to_string())

# d. Descriptive statistics for "Price"
print("\nDescriptive Statistics for Price:")
print(fruits_df["Price"].describe())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fruit   5 non-null      object
#  1   Price   5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes
# None
#
# Full DataFrame:
#     Fruit  Price
# 0   Apple    120
# 1  Banana     40
# 2  Cherry    200
# 3   Mango    150
# 4  Orange     80
#
# Descriptive Statistics for Price:
# count      5.000000
# mean     118.000000
# std       61.806149
# min       40.000000
# 25%       80.000000
# 50%      120.000000
# 75%      150.000000
# max      200.000000
# Name: Price, dtype: float64
